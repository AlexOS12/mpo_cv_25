# %% [markdown]
# # Облученность приемника
# *от 13.02.2025*

# %%
import numpy as np
from matplotlib import pyplot as plt
from math import cos

# %%
# Константы

# %%
# Входные данные
L0 = 1.23
dAs = 5 # площадь источника света
F = 1   # фокусное растояние линзы
Z = 2   # растояние от объекта до линзы
Alpha = 30
Theta = 45

# %%
dAi = dAs / ((cos(Alpha)/cos(Theta)) * (Z/F)**2)
dAi
# Out:
# 4.257026345624108
